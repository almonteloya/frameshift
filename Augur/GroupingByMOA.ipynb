# %%
import pandas as pd
from glob import glob

# %%
def parse_out(path):
	files = glob(path + "/*.csv")
	dfs = {}
	for f in files:
		base_name = f.split("/")[-1].split(".csv")[0]
		plate, drug = base_name.split("__")
		# drug, plate 
		df = pd.read_csv(f)
		df['plate'] = plate
		df.set_index(['plate', 'drug'], inplace=True)
		dfs[(plate, drug)] = df.iloc[0,:]
	dfs = pd.concat(dfs, axis=1).T.reset_index().rename(columns={"level_0": "plate", "level_1": "drug"})
	return(dfs)


path = "/home/ubuntu/frameshift-1/data/augur_out/scores"
scores = parse_out(path)

scores = scores.groupby('drug').mean(numeric_only=True)
print(scores.shape)
scores.head()
# Out:
# (48, 50)
#                               NCI-H1573  NCI-H460  hTERT-HPNE      SW48  \
# drug
# [('Aprepitant', 0.05, 'uM')]   0.522415  0.517710    0.541791  0.487937
# [('Ataluren', 0.05, 'uM')]     0.504082  0.524348    0.499518  0.518566
# [('Ataluren', 0.5, 'uM')]      0.484949  0.470833    0.478458  0.485771
# [('Belinostat', 0.05, 'uM')]   0.531712  0.534932    0.502098  0.523424
# [('Belinostat', 0.5, 'uM')]    0.573526  0.572959    0.519700  0.560856
#
#                                  HOP62  NCI-H1792     SW480     HT-29  \
# drug
# [('Aprepitant', 0.05, 'uM')]  0.547177   0.555680  0.545045  0.531043
# [('Ataluren', 0.05, 'uM')]    0.541695   0.468537  0.507285  0.500397
# [('Ataluren', 0.5, 'uM')]     0.490731   0.443311  0.520748  0.504167
# [('Belinostat', 0.05, 'uM')]  0.518787   0.555658  0.509082  0.534671
# [('Belinostat', 0.5, 'uM')]   0.551105   0.582370  0.531179  0.603345
#
#                                   LoVo   Hs 766T  ...  NCI-H2030       C32  \
# drug                                              ...
# [('Aprepitant', 0.05, 'uM')]  0.540340  0.524365  ...   0.545760  0.552063
# [('Ataluren', 0.05, 'uM')]    0.526389  0.457370  ...   0.499320  0.517744
# [('Ataluren', 0.5, 'uM')]     0.508362  0.504847  ...   0.570578  0.472676
# [('Belinostat', 0.05, 'uM')]  0.520385  0.504320  ...   0.515624  0.472154
# [('Belinostat', 0.5, 'uM')]   0.534892  0.542942  ...   0.553260  0.534580
#
#                               HepG2/C3A    AsPC-1   CHP-212   SW 1088  \
# drug
# [('Aprepitant', 0.05, 'uM')]   0.494376  0.485760  0.535023  0.496655
# [('Ataluren', 0.05, 'uM')]     0.588379  0.485658  0.473214  0.481122
# [('Ataluren', 0.5, 'uM')]      0.526247  0.535629  0.506888  0.498129
# [('Belinostat', 0.05, 'uM')]   0.513628  0.500283  0.532483  0.518175
# [('Belinostat', 0.5, 'uM')]    0.585091  0.583787  0.537727  0.527381
#
#                                  A-427  NCI-H661  NCI-H2122  NCI-H596
# drug
# [('Aprepitant', 0.05, 'uM')]  0.535159  0.514535   0.501372       0.5
# [('Ataluren', 0.05, 'uM')]    0.494444  0.468141   0.481944       0.5
# [('Ataluren', 0.5, 'uM')]     0.535147  0.528883        NaN       0.5
# [('Belinostat', 0.05, 'uM')]  0.556746  0.512483   0.473571       0.5
# [('Belinostat', 0.5, 'uM')]   0.530612  0.570833        NaN       NaN
#
# [5 rows x 50 columns]

# %%
scores.max(axis=1).sort_values()
# Out:
# drug
# [('Omeprazole', 0.5, 'uM')]                        0.536706
# [('Econazole', 0.05, 'uM')]                        0.543254
# [('Imiquimod (hydrochloride)', 0.5, 'uM')]         0.546287
# [('Ponatinib', 0.05, 'uM')]                        0.547608
# [('Imiquimod (hydrochloride)', 0.05, 'uM')]        0.548787
# [('Fingolimod (hydrochloride)', 0.05, 'uM')]       0.552268
# [('Tirabrutinib (hydrochloride)', 0.05, 'uM')]     0.554478
# [('Brimonidine', 0.05, 'uM')]                      0.554734
# [('Vortioxetine', 0.05, 'uM')]                     0.555669
# [('Aprepitant', 0.05, 'uM')]                       0.555680
# [('Oxaprozin', 0.05, 'uM')]                        0.556032
# [('Cabozantinib (S-malate)', 0.05, 'uM')]          0.557313
# [('Loperamide (hydrochloride)', 0.5, 'uM')]        0.557880
# [('Indacaterol (maleate)', 0.05, 'uM')]            0.559138
# [('Omeprazole', 0.05, 'uM')]                       0.560283
# [('Phenylephrine (hydrochloride)', 0.5, 'uM')]     0.560629
# [('Drospirenone', 0.05, 'uM')]                     0.560748
# [('Benztropine (mesylate)', 0.05, 'uM')]           0.561077
# [('Entrectinib', 0.05, 'uM')]                      0.561485
# [('Belinostat', 0.05, 'uM')]                       0.561712
# [('Brimonidine', 0.5, 'uM')]                       0.563039
# [('Phenylephrine (hydrochloride)', 0.05, 'uM')]    0.563741
# [('Esmolol (hydrochloride)', 0.05, 'uM')]          0.563804
# [('Loperamide (hydrochloride)', 0.05, 'uM')]       0.563900
# [('Canagliflozin (hemihydrate)', 0.05, 'uM')]      0.570323
# [('Filgotinib', 0.5, 'uM')]                        0.570408
# [('Ataluren', 0.5, 'uM')]                          0.570578
# [('Vitamin K4', 0.05, 'uM')]                       0.573095
# [('Esmolol (hydrochloride)', 0.5, 'uM')]           0.574206
# [('Benztropine (mesylate)', 0.5, 'uM')]            0.574490
# [('Econazole', 0.5, 'uM')]                         0.576757
# [('Vortioxetine', 0.5, 'uM')]                      0.580669
# [('Omeprazole (sodium)', 0.5, 'uM')]               0.585488
# [('Omeprazole (sodium)', 0.05, 'uM')]              0.586905
# [('Fingolimod (hydrochloride)', 0.5, 'uM')]        0.586933
# [('Ataluren', 0.05, 'uM')]                         0.588379
# [('Bestatin (hydrochloride)', 0.05, 'uM')]         0.589654
# [('Filgotinib', 0.05, 'uM')]                       0.589909
# [('Bicalutamide', 0.05, 'uM')]                     0.595397
# [('Entrectinib', 0.5, 'uM')]                       0.602041
# [('Drospirenone', 0.5, 'uM')]                      0.602721
# [('Ponatinib', 0.5, 'uM')]                         0.603316
# [('Belinostat', 0.5, 'uM')]                        0.603345
# [('Indacaterol (maleate)', 0.5, 'uM')]             0.605045
# [('Bestatin (hydrochloride)', 0.5, 'uM')]          0.607483
# [('Cabozantinib (S-malate)', 0.5, 'uM')]           0.609070
# [('Tirabrutinib (hydrochloride)', 0.5, 'uM')]      0.611395
# [('Digitoxin', 0.05, 'uM')]                        0.648016
# dtype: float64
